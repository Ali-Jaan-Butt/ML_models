# %% [markdown]
# <center><h1>Model about Student Progress Prediction</h1></center>

# %% [markdown]
# <h3>Importing Libraries</h3>

# %% [markdown]
# Importing libraries is the initial step of every action, without it we cannot perform any action on the data.
# Importing "pandas" is for reading csv file from the directory, and also perform some basic analysis.
# Importing "numpy" is for performing mathematical operation on the data
# Importing "matplotlib" is for analysis and for visualization of the data in the notebook. It used single or multiple columns to perform visualization and graphs.
# Importing "seaborn" is also for analysis and visualization of data into graphs. Also show their corelation with each other.
# After that imported model libraries from sklearn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from bokeh.plotting import figure, output_file, show
from bokeh.palettes import magma

# %% [markdown]
# Now, we are going to read that csv file cointaining all the data on which we are going to perform analysis and also train a model.
# After reading that file we are saving that dataframe into a datraframe variable named "df".

# %%
df = pd.read_csv('data.csv', delimiter=';')

# %% [markdown]
# <h2>Exploratory Data Analysis</h2>

# %% [markdown]
# <h3>Basic Analysis</h3>

# %% [markdown]
# Here is the sample display of the dataframe containing all data/information.
# This sample data contains unique random rows of the dataset.

# %%
df.sample(10)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4316               1                 1                  3    9070
# 1887               2                43                  1    9773
# 939                4                39                  1    8014
# 1206               1                43                  2    9500
# 818                1                17                  2    9500
# 77                 1                17                  4    9773
# 4072               2                39                  1    9238
# 929                1                 1                  1    9238
# 213                1                39                  1    9991
# 3522               1                 1                  1    9670
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4316                             1                       1
# 1887                             1                       1
# 939                              0                      19
# 1206                             1                       1
# 818                              1                       1
# 77                               1                       1
# 4072                             1                      19
# 929                              1                       1
# 213                              0                       1
# 3522                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4316                           118.0            1                      43
# 1887                           160.0            1                      37
# 939                            133.1            1                      37
# 1206                           120.0            1                      37
# 818                            132.0            1                      19
# 77                             121.0            1                       1
# 4072                           133.1            1                       1
# 929                            133.1            1                      19
# 213                            133.1            1                      37
# 3522                           146.0            1                       1
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 4316                       3  ...                                    0
# 1887                      37  ...                                    0
# 939                       37  ...                                    0
# 1206                      34  ...                                   11
# 818                       37  ...                                    0
# 77                        19  ...                                    0
# 4072                       2  ...                                    0
# 929                       37  ...                                    0
# 213                       37  ...                                    0
# 3522                       1  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 4316                                    6
# 1887                                    4
# 939                                     6
# 1206                                   14
# 818                                     8
# 77                                      6
# 4072                                    6
# 929                                     6
# 213                                     5
# 3522                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 4316                                       7
# 1887                                       4
# 939                                        9
# 1206                                      14
# 818                                       10
# 77                                         6
# 4072                                       8
# 929                                        0
# 213                                        8
# 3522                                       8
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 4316                                    6                         13.571429
# 1887                                    0                          0.000000
# 939                                     3                         11.000000
# 1206                                   12                         12.333333
# 818                                     7                         13.164286
# 77                                      6                         13.333333
# 4072                                    6                         13.000000
# 929                                     0                          0.000000
# 213                                     0                          0.000000
# 3522                                    6                         13.428571
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 4316                                               0                8.9
# 1887                                               0               12.7
# 939                                                0                9.4
# 1206                                               2                7.6
# 818                                                0               11.1
# 77                                                 0                8.9
# 4072                                               0                9.4
# 929                                                0                7.6
# 213                                                0               16.2
# 3522                                               0               11.1
#
#       Inflation rate   GDP    Target
# 4316             1.4  3.51  Graduate
# 1887             3.7 -1.70   Dropout
# 939             -0.8 -3.12   Dropout
# 1206             2.6  0.32  Graduate
# 818              0.6  2.02  Enrolled
# 77               1.4  3.51  Graduate
# 4072            -0.8 -3.12  Enrolled
# 929              2.6  0.32   Dropout
# 213              0.3 -0.92   Dropout
# 3522             0.6  2.02  Graduate
#
# [10 rows x 37 columns]

# %% [markdown]
# Lets do Label encode to the dataset

# %%
label = LabelEncoder()

# %% [markdown]
# Encoding the two columns of dataset

# %%
df['Target'] = label.fit_transform(df['Target'])

# %% [markdown]
# Here is the head of the dataframe, which means that starting rows of the dataframe. It doesn't means that they should be unique, but it can be.

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
# 4                           100.0            1                      37
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                      12  ...                                    0
# 1                       3  ...                                    0
# 2                      37  ...                                    0
# 3                      37  ...                                    0
# 4                      38  ...                                    0
#
#    Curricular units 2nd sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       2
# 2             1.4  1.74       0
# 3            -0.8 -3.12       2
# 4            -0.3  0.79       2
#
# [5 rows x 37 columns]

# %% [markdown]
# Here is the tail of the dataset, which means that ending rows of the dataset. It doesn't means that it should be unique but it can be.

# %%
df.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# 4420                           120.0          105                       1
# 4421                           154.0            1                      37
# 4422                           180.0            1                      37
# 4423                           152.0           22                      38
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 4419                       1  ...                                    0
# 4420                       1  ...                                    0
# 4421                      37  ...                                    0
# 4422                      37  ...                                    0
# 4423                      37  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 4419                                    5                         12.666667
# 4420                                    2                         11.000000
# 4421                                    1                         13.500000
# 4422                                    5                         12.000000
# 4423                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 4419                                               0               15.5
# 4420                                               0               11.1
# 4421                                               0               13.9
# 4422                                               0                9.4
# 4423                                               0               12.7
#
#       Inflation rate   GDP  Target
# 4419             2.8 -4.06       2
# 4420             0.6  2.02       0
# 4421            -0.3  0.79       0
# 4422            -0.8 -3.12       2
# 4423             3.7 -1.70       2
#
# [5 rows x 37 columns]

# %% [markdown]
# Here is the basic information of the dataset, it includes value counts, datatypes and empty rows imformation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
#  9   Father's qualification                          4424 non-null   int64
#  10  Mother's occupation                             4424 non-null   int64
#  11  Father's occupation                             4424 non-null   int64
#  12  Admission grade                                 4424 non-null   float64
#  13  Displaced                                       4424 non-null   int64
#  14  Educational special needs                       4424 non-null   int64
#  15  Debtor                                          4424 non-null   int64
#  16  Tuition fees up to date                         4424 non-null   int64
#  17  Gender                                          4424 non-null   int64
#  18  Scholarship holder                              4424 non-null   int64
#  19  Age at enrollment                               4424 non-null   int64
#  20  International                                   4424 non-null   int64
#  21  Curricular units 1st sem (credited)             4424 non-null   int64
#  22  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  23  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  24  Curricular units 1st sem (approved)             4424 non-null   int64
#  25  Curricular units 1st sem (grade)                4424 non-null   float64
#  26  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  27  Curricular units 2nd sem (credited)             4424 non-null   int64
#  28  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  29  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  30  Curricular units 2nd sem (approved)             4424 non-null   int64
#  31  Curricular units 2nd sem (grade)                4424 non-null   float64
#  32  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  33  Unemployment rate                               4424 non-null   float64
#  34  Inflation rate                                  4424 non-null   float64
#  35  GDP                                             4424 non-null   float64
#  36  Target                                          4424 non-null   int64
# dtypes: float64(7), int64(30)
# memory usage: 1.2 MB

# %% [markdown]
# Here is the more information about the dataset. Describe shows the mean, avg, percentages, etc of the dataset columns.

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# 25%                        1.000000                1.000000
# 50%                        1.000000                1.000000
# 75%                        1.000000                1.000000
# max                        1.000000               43.000000
#
#        Previous qualification (grade)  Nacionality  Mother's qualification  \
# count                     4424.000000  4424.000000             4424.000000
# mean                       132.613314     1.873192               19.561935
# std                         13.188332     6.914514               15.603186
# min                         95.000000     1.000000                1.000000
# 25%                        125.000000     1.000000                2.000000
# 50%                        133.100000     1.000000               19.000000
# 75%                        140.000000     1.000000               37.000000
# max                        190.000000   109.000000               44.000000
#
#        Father's qualification  ...  Curricular units 2nd sem (credited)  \
# count             4424.000000  ...                          4424.000000
# mean                22.275316  ...                             0.541817
# std                 15.343108  ...                             1.918546
# min                  1.000000  ...                             0.000000
# 25%                  3.000000  ...                             0.000000
# 50%                 19.000000  ...                             0.000000
# 75%                 37.000000  ...                             0.000000
# max                 44.000000  ...                            19.000000
#
#        Curricular units 2nd sem (enrolled)  \
# count                          4424.000000
# mean                              6.232143
# std                               2.195951
# min                               0.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                              23.000000
#
#        Curricular units 2nd sem (evaluations)  \
# count                             4424.000000
# mean                                 8.063291
# std                                  3.947951
# min                                  0.000000
# 25%                                  6.000000
# 50%                                  8.000000
# 75%                                 10.000000
# max                                 33.000000
#
#        Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# count                          4424.000000                       4424.000000
# mean                              4.435805                         10.230206
# std                               3.014764                          5.210808
# min                               0.000000                          0.000000
# 25%                               2.000000                         10.750000
# 50%                               5.000000                         12.200000
# 75%                               6.000000                         13.333333
# max                              20.000000                         18.571429
#
#        Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# count                                     4424.000000        4424.000000
# mean                                         0.150316          11.566139
# std                                          0.753774           2.663850
# min                                          0.000000           7.600000
# 25%                                          0.000000           9.400000
# 50%                                          0.000000          11.100000
# 75%                                          0.000000          13.900000
# max                                         12.000000          16.200000
#
#        Inflation rate          GDP       Target
# count     4424.000000  4424.000000  4424.000000
# mean         1.228029     0.001969     1.178119
# std          1.382711     2.269935     0.888243
# min         -0.800000    -4.060000     0.000000
# 25%          0.300000    -1.700000     0.000000
# 50%          1.400000     0.320000     1.000000
# 75%          2.600000     1.790000     2.000000
# max          3.700000     3.510000     2.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# By manually analyzing, we can say that the target class is Level, as it includes status of the cancer. Let's have analysis on the whole dataset on the basis of the target class.

# %% [markdown]
# <h3>Univariate Analysis</h3>

# %% [markdown]
# Univariate analysis means that analysis made on single column

# %% [markdown]
# Lets get the percentage of the target class. By pie chart we can easily get the percentage and numbers of the target class or any class

# %%
df['Target'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='Target'>

# %% [markdown]
# Lets draw a histogram on a single column.
# It shows the histology of the data on a graph
# And we use this to get the frequency of the data in the dataframe

# %%
plt.hist(df['Target'])
# Out:
# (array([1421.,    0.,    0.,    0.,    0.,  794.,    0.,    0.,    0.,
#         2209.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Lets draw a distribution plot on the same data. It shows the distribution among the values of the column. And we use this to get the distribution among the frequency of the dataset.
# Setting histogram to false means that excluding the histogram from the graph

# %%
sns.distplot(df['Tuition fees up to date'], hist=False)
# Out:
# /var/folders/bh/phg5j6rx557fc31zr9pgztnr0000gn/T/ipykernel_1958/2854048237.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Tuition fees up to date'], hist=False)
# <Axes: xlabel='Tuition fees up to date', ylabel='Density'>

# %% [markdown]
# Histogram on page rank column to check the frequency of the data.

# %%
sns.histplot(df['Scholarship holder'])
# Out:
# <Axes: xlabel='Scholarship holder', ylabel='Count'>

# %% [markdown]
# Plotting box plot: This shows the outliers of the data. The outliers are not acceptable for the accurate model. So we have to detect them.

# %%
sns.boxplot(df['GDP'])
# Out:
# <Axes: >

# %% [markdown]
# Also check the outliers of the domain age

# %%
sns.boxplot(df['Target'])
# Out:
# <Axes: >

# %% [markdown]
# Lets plot a scatter plot to get the values at different points of the graph
# The dark lines shows that there are more points that means it shows the distribution of the values at different points

# %%
sns.scatterplot(df['Unemployment rate'])
# Out:
# <Axes: ylabel='Unemployment rate'>

# %% [markdown]
# If we do scatter plot for the target class we will get equal distribution at two lines

# %%
sns.scatterplot(df['Admission grade'])
# Out:
# <Axes: ylabel='Admission grade'>

# %% [markdown]
# We can see the distributions by bar plot

# %% [markdown]
# <h3>Bivariate Analysis</h3>

# %% [markdown]
# In bivariate analysis, we do analysis by comparising two columns on the basis of their corelation.
# And we also examine the corelation among the two columns.

# %%
df.sample(10)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 1607               1                 1                  6    9500
# 4253               1                18                  2    9853
# 69                 1                39                  1    9254
# 1389               1                 1                  2    9085
# 2649               1                 1                  1    9500
# 489                1                 1                  3    9500
# 298                1                17                  4    9556
# 86                 1                39                  1    9670
# 2975               5                43                  1    9991
# 2060               1                17                  6    9500
#
#       Daytime/evening attendance\t  Previous qualification  \
# 1607                             1                       1
# 4253                             1                       1
# 69                               1                       1
# 1389                             1                       1
# 2649                             1                       1
# 489                              1                       1
# 298                              1                       1
# 86                               1                       1
# 2975                             0                       3
# 2060                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 1607                           141.0            1                       4
# 4253                           120.0            1                      19
# 69                             160.0            1                      19
# 1389                           118.0            1                       1
# 2649                           125.0            1                      19
# 489                            128.0            1                      38
# 298                            112.0            1                       1
# 86                             120.0            1                       1
# 2975                           130.0            1                       3
# 2060                           126.0            1                      19
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 1607                       3  ...                                    0
# 4253                      37  ...                                    0
# 69                        37  ...                                    0
# 1389                      19  ...                                    0
# 2649                      38  ...                                    0
# 489                       38  ...                                    0
# 298                        1  ...                                    0
# 86                        19  ...                                    0
# 2975                       3  ...                                    5
# 2060                      37  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 1607                                    8
# 4253                                    7
# 69                                      6
# 1389                                    5
# 2649                                    8
# 489                                     8
# 298                                     8
# 86                                      5
# 2975                                   10
# 2060                                    8
#
#       Curricular units 2nd sem (evaluations)  \
# 1607                                       9
# 4253                                      13
# 69                                         8
# 1389                                      15
# 2649                                      12
# 489                                        8
# 298                                        8
# 86                                         7
# 2975                                      13
# 2060                                       9
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 1607                                    8                         12.887500
# 4253                                    0                          0.000000
# 69                                      5                         10.800000
# 1389                                    3                         10.600000
# 2649                                    5                         12.002000
# 489                                     7                         13.542857
# 298                                     8                         13.137500
# 86                                      5                         11.600000
# 2975                                   10                         14.600000
# 2060                                    8                         13.666667
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 1607                                               1                9.4
# 4253                                               0               12.4
# 69                                                 0               12.7
# 1389                                               4               10.8
# 2649                                               1               10.8
# 489                                                0               13.9
# 298                                                0               12.4
# 86                                                 0                9.4
# 2975                                               0               16.2
# 2060                                               0               16.2
#
#       Inflation rate   GDP  Target
# 1607            -0.8 -3.12       2
# 4253             0.5  1.79       0
# 69               3.7 -1.70       1
# 1389             1.4  1.74       1
# 2649             1.4  1.74       0
# 489             -0.3  0.79       2
# 298              0.5  1.79       2
# 86              -0.8 -3.12       2
# 2975             0.3 -0.92       2
# 2060             0.3 -0.92       2
#
# [10 rows x 37 columns]

# %% [markdown]
# Let's plot scatter plot on two columns on the basis of the relation.
# This is to be done to show the relation between the two columns.

# %%
plt.scatter(x = df["Mother's qualification"], y = df["Father's qualification"])

# %% [markdown]
# Let's plot a scatter plot of the target class with the other class to get the relation of the classes

# %%
plt.scatter(x = df['GDP'], y = df['Target'])

# %% [markdown]
# Now, lets draw a scatter plot of two different classes with hue of the target class

# %%
sns.scatterplot(x = df['Unemployment rate'], y = df['Inflation rate'], hue = df['Target'], style = df['Nacionality'], size = df['Marital status'])
# Out:
# <Axes: xlabel='Unemployment rate', ylabel='Inflation rate'>

# %% [markdown]
# Draw barplot having hue of the target class

# %%
sns.barplot(x = df['GDP'], y = df['Inflation rate'], hue = df['Target'])
# Out:
# <Axes: xlabel='GDP', ylabel='Inflation rate'>

# %% [markdown]
# Lets draw a boxplot on two columns with hue of the class.
# We do this to detect the outliers of the dataset in different classes.
# These outliers usually effect the dataset's accuracy and processing.

# %%
sns.boxplot(x = df['GDP'], y = df['Target'], hue = df['Marital status'])
# Out:
# <Axes: xlabel='GDP', ylabel='Target'>

# %% [markdown]
# Distribution plot is for getting the frequency of the data on a graph

# %%
sns.kdeplot(x = df['Target'], y = df['Inflation rate'])
# Out:
# <Axes: xlabel='Target', ylabel='Inflation rate'>

# %% [markdown]
# Draw a heatmap to get the corelated columns and useful features

# %%
sns.heatmap(pd.crosstab(df['Target'],df['Gender']), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: xlabel='Gender', ylabel='Target'>

# %% [markdown]
# <h3>Multi-variate Analysis</h3>

# %% [markdown]
# Lets do multivariate analysis on the dataset in this analysis we will have analysis on all of the columns with all of the relation with all of them

# %% [markdown]
# Calculating the distributions of the data to get an efficient heatmap.
# Dividing dataframe into 3 parts

# %%
dist_df = int(np.ceil(37/4))
df1 = df[:dist_df]
df1 = df[df.columns[:dist_df]]
df2 = df[df.columns[dist_df:dist_df+dist_df]]
df3 = df[df.columns[dist_df+dist_df:dist_df+dist_df+dist_df]]
df4 = df[df.columns[dist_df+dist_df+dist_df:]]

# %% [markdown]
# Let's draw heatmap so that we can have complete analysis of the featues and then we will remove the non essential features from the data to get efficient accuracy.
# This is not accurate solution so we are going to perform it on specific columns

# %%
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# /Users/hassanazhar/anaconda3/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# <Axes: >
# /Users/hassanazhar/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /Users/hassanazhar/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Let's draw heatmap for another one so that we can have complete analysis of the featues and then we will remove the non essential features from the data to get efficient accuracy.
# This is not accurate solution so we are going to perform it on specific columns

# %%
sns.heatmap(df2.corr(), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# Let's draw heatmap for another one so that we can have complete analysis of the featues and then we will remove the non essential features from the data to get efficient accuracy.
# This is not accurate solution so we are going to perform it on specific columns

# %%
sns.heatmap(df3.corr(), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# Let's draw heatmap for another one so that we can have complete analysis of the featues and then we will remove the non essential features from the data to get efficient accuracy.
# This is not accurate solution so we are going to perform it on specific columns

# %%
sns.heatmap(df4.corr(), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
sample_df = df[['Gender','Unemployment rate','GDP','Target']]
sns.heatmap(sample_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# Lets draw a pairplot to get multivariate analysis

# %%
sns.pairplot(sample_df, hue = 'Target')

# %% [markdown]
# <h2>Aplying Algorithm</h2>

# %% [markdown]
# "x" contains all the data exluding the target class

# %%
x = df.drop(columns = 'Target')

# %% [markdown]
# "y" contains the target class

# %%
y = df['Target']

# %% [markdown]
# Now split the data into training and testing

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# Creating Random Forest object

# %%
rf_classifier = RandomForestClassifier(n_estimators=12, random_state=42)

# %% [markdown]
# Training model on training data

# %%
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=12, random_state=42)

# %% [markdown]
# This will get the predicion of the model from the texting data

# %%
y_pred = rf_classifier.predict(x_test)

# %% [markdown]
# Let's get the accuracy of the model

# %%
accuracy = accuracy_score(y_test, y_pred)

# %% [markdown]
# This will show the accuracy of the model multiplying it by 100

# %%
print("Accuracy:", accuracy*100)
# Out:
# Accuracy: 74.77396021699819

# %% [markdown]
# <h2>Visualization</h2>

# %% [markdown]
# Lets visualize the predicted data to show the progress

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_test, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('True vs Predicted Labels')
plt.grid(True)
plt.show()

# %% [markdown]
# Visualization on distribution plot

# %%
plt.figure(figsize=(8, 6))
sns.histplot(y_pred, bins=10, kde=True, color='skyblue')
plt.xlabel('Predicted Labels')
plt.ylabel('Density')
plt.title('Distribution of Predicted Labels')
plt.show()

# %% [markdown]
# <h2>Classification Report</h2>

# %% [markdown]
# Generate classification report get information about
# Percision
# Recall
# F1_score
# Support

# %%
report = classification_report(y_test, y_pred)

# %% [markdown]
# Show the report

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77       374
#            1       0.48      0.31      0.38       197
#            2       0.79      0.90      0.84       535
#
#     accuracy                           0.75      1106
#    macro avg       0.68      0.66      0.66      1106
# weighted avg       0.73      0.75      0.73      1106

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %% [markdown]
# Creating confusion matrix of the predicted data

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# %% [markdown]
# Showing confusion matrix

# %%
print(conf_matrix)
# Out:
# [[286  34  54]
#  [ 61  62  74]
#  [ 24  32 479]]

# %% [markdown]
# This is how a confusion matrix looks like

# %% [raw]
#                        Predicted Class
#              |    Positive    |    Negative    |
# Actual Class |                |                |
#              |----------------|----------------|
# Positive     | True Positive  | False Negative |
# Negative     | False Positive | True Negative  |

# %% [markdown]
# Visualizing the confusion matrix

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
